# %%
# Load required libraries
from sklearn import tree
import sklearn.tree
from sklearn.linear_model import Perceptron
from sklearn.model_selection import train_test_split
from sklearn.model_selection import ShuffleSplit
from sklearn.metrics import accuracy_score
from sklearn.metrics import roc_curve
from sklearn.metrics import auc
from sklearn.ensemble import AdaBoostClassifier
import numpy as np 
import matplotlib.pyplot as plt
import pandas as pd
import statistics 
import math
import random
from sklearn.neighbors import KNeighborsClassifier
import time
from time import process_time
from sklearn.metrics import f1_score, make_scorer
from sklearn.metrics import recall_score
from sklearn.metrics import precision_score
from sklearn.neural_network import MLPClassifier
from sklearn.model_selection import validation_curve
from sklearn.model_selection import GridSearchCV

# %%
t_size= 3
p_size= 3

# %%
#Read files
# refdata= pd.read_csv("./Final dataset_2/features_list.txt", header=None) #120 features
df= pd.read_csv(f"./Final dataset_3/dataset_norm_t{t_size}_p{p_size}.csv", index_col= None)
type(df)
# print(df.shape)
df.describe().transpose()

# Creating array
target_column= ['label']

predictors= list(set(list(df.columns))-set(target_column))
X=df[predictors].values
y= df[target_column].values

#Train-Test Split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, shuffle=True, stratify= y, random_state=10)

print(X_train.shape); print(X_test.shape)
print(y_train.shape); print(y_test.shape)
# Out:
# (4505, 92)
# (1932, 92)
# (4505, 1)
# (1932, 1)

# %%
#Read files with PCA
refdata= pd.read_csv("./Final dataset_3/features.txt", header=None) #92 features
df= pd.read_csv(f"./PCA/dataset_norm_t8_p8_45f_pca.csv", index_col= None)
# df= pd.read_csv(f"./PCA/dataset_norm_t8_p8_45f.csv", index_col= None)
# type(df)
# print(df.shape)
df.describe().transpose()

# Creating array


predictors=['PC1', 'PC2', 'PC3', 'PC4', 'PC5', 'PC6', 'PC7', 'PC8', 'PC9', 'PC10', 'PC11', 'PC12', 'PC13', 'PC14']
target_column= ['label']

# predictors= list(set(list(df.columns))-set(target_column))

X=df[predictors].values
y= df[target_column].values

#Train-Test Split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, shuffle=True, stratify= y, random_state=10)

print(X_train.shape); print(X_test.shape)
print(y_train.shape); print(y_test.shape)
print(X)

# %%
##Hyperparameter tuning considering F1 Score
import time

f1= make_scorer(f1_score, average='macro')

parameters={
'hidden_layer_sizes': [(5,), (8,), (10,), (12,), (15,), (18,), (20,), (22,)],
'activation': ['tanh', 'relu', 'logistic'],
'solver': ['adam', 'lbfgs', 'sgd'],
'alpha': [0.1, 0.01, 0.001, 0.0001],
'max_iter': [50, 100, 300, 500, 1000, 1500],
'batch_size' : [1, 64, 4505]
}
 
clf = GridSearchCV(MLPClassifier(), parameters, n_jobs=-1, scoring=f1, verbose=500)
t1=time.time()
clf.fit(X_train, y_train)
t2=time.time()  
    
print("Classification time:",str(t2-t1)," seconds")
print(clf.score(X_train, y_train.ravel()))
print(clf.score(X_test, y_test))
print(clf.best_params_)
# Out:
# Fitting 5 folds for each of 5184 candidates, totalling 25920 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# Memmapping (shape=(4505, 92), dtype=float64) to new file C:\Users\mnsak\AppData\Local\Temp\joblib_memmapping_folder_21072_6974660031\21072-1872106433288-422db4e81f054cc4be5c13fa90a16846.pkl
# Pickling array (shape=(4505, 1), dtype=float64).
# Pickling array (shape=(3604,), dtype=int32).
# Pickling array (shape=(901,), dtype=int32).
# Memmapping (shape=(4505, 92), dtype=float64) to old file C:\Users\mnsak\AppData\Local\Temp\joblib_memmapping_folder_21072_6974660031\21072-1872106433288-422db4e81f054cc4be5c13fa90a16846.pkl
# Pickling array (shape=(4505, 1), dtype=float64).
# Pickling array (shape=(3604,), dtype=int32).
# Pickling array (shape=(901,), dtype=int32).
# ...

# %%
##Hyperparameter tuning considering F1 Score
import time

f1= make_scorer(f1_score, average='macro')

parameters={
'hidden_layer_sizes': [(18,10), (18,15), (18,18), (18,20), (18,25), (15,15), (10,10)],
'activation': ['tanh', 'relu'],
'solver': ['adam'],
'alpha': [0.001, 0.0001],
'max_iter': [500, 1000],
'batch_size' : [1, 64]
}
 
clf = GridSearchCV(MLPClassifier(), parameters, n_jobs=-1, scoring=f1)
t1=time.time()
clf.fit(X_train, y_train.ravel())
t2=time.time()  
    
print("Classification time:",str(t2-t1)," seconds")
print(clf.score(X_train, y_train.ravel()))
print(clf.score(X_test, y_test))
print(clf.best_params_)

# %% [markdown]
# ### dependency on learning rate (sgd)

# %%
parameters={
#'hidden_layer_sizes': [(4,3)],
    
'hidden_layer_sizes': [(5,5)],
'activation': ['tanh'],
'solver': ['adam'],   
'alpha': [0.01, 0.001, 0.0001],
'learning_rate': ['constant','adaptive', 'invscaling'],
'max_iter': [50],
'batch_size' : [1]
}

clf = GridSearchCV(MLPClassifier(), parameters, n_jobs=-1)

clf.fit(X_train, y_train)
print(clf.score(X_train, y_train))
print(clf.score(X_test, y_test))
print(clf.best_params_)

# %%
parameters={
#'hidden_layer_sizes': [(4,3)],
    
'hidden_layer_sizes': [(5,5)],
'activation': ['tanh'],
'solver': ['adam'],   
'alpha': [0.01],
'learning_rate': ['constant'],
'max_iter': [50],
'batch_size' : [1]
}

clf = GridSearchCV(MLPClassifier(), parameters, n_jobs=-1)

clf.fit(X_train, y_train)
print(clf.score(X_train, y_train))
print(clf.score(X_test, y_test))
print(clf.best_params_)
